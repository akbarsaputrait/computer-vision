# %% [markdown]
# <a href="https://colab.research.google.com/github/akbarsaputrait/computer-vision/blob/main/opencv_basic/split_merge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://krs.umm.ac.id/Poto/2019/201910370311145.JPG --no-check-certificate
# Out:
# --2021-11-09 04:01:23--  https://krs.umm.ac.id/Poto/2019/201910370311145.JPG
# Resolving krs.umm.ac.id (krs.umm.ac.id)... 202.52.52.26
# Connecting to krs.umm.ac.id (krs.umm.ac.id)|202.52.52.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34554 (34K) [image/jpeg]
# Saving to: ‘201910370311145.JPG’
#
# 201910370311145.JPG 100%[===================>]  33.74K   148KB/s    in 0.2s
#
# 2021-11-09 04:01:25 (148 KB/s) - ‘201910370311145.JPG’ saved [34554/34554]

# %%
# import the necessary packages
from matplotlib import pyplot as plt
import numpy as np
import argparse
import cv2

# %%
def plt_imshow(title, image):
	# convert the image frame BGR to RGB color space and display it
	image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
	plt.imshow(image)
	plt.title(title)
	plt.grid(False)
	plt.show()

# %%
# since we are using Jupyter Notebooks we can replace our argument
# parsing code with *hard coded* arguments and values
args = {
	"image": "201910370311145.JPG"
}

# %%
# load the input image and grab each channel -- note how OpenCV
# represents images as NumPy arrays with channels in Blue, Green,
# Red ordering rather than Red, Green Blue
image = cv2.imread(args["image"])
(B, G, R) = cv2.split(image)

# show each channel individually
plt_imshow("Red", R)
plt_imshow("Green", G)
plt_imshow("Blue", B)

# %%
merged = cv2.merge([B, G, R])
plt_imshow("Merged", merged)

# %%
# visualize each channel in color
zeros = np.zeros(image.shape[:2], dtype="uint8")
plt_imshow("Red", cv2.merge([zeros, zeros, R]))
plt_imshow("Green", cv2.merge([zeros, G, zeros]))
plt_imshow("Blue", cv2.merge([B, zeros, zeros]))
